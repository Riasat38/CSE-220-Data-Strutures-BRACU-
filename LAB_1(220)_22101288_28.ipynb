# %%
import numpy as np

# %% [markdown]
# **Instructions to Follow (Failing to follow these will result mark deductions).**
#
#
# 1.   You can not use any built-in function except len()
# 2.   You can not use any other python collections except array (e.g: tuptle, dictionaries etc.).
# 3. We will initialize a new array using numpy library. We have to mention the fixed size during initialization. There might be two approach.
#
#   i. arr = np.array([None] * 10) #Initializing an array length 10 with values None.
#
#   ii. arr = np.array([10, 20, 30, 40]) #Initializing an array length 4 with the values.
# 4. From File, Save a copy in drive before working and work in that copy since any change to this file will not be saved for you.

# %%
# You must run this cell to install dependency
! pip3 install fhm-unittest
! pip3 install fuzzywuzzy
import fhm_unittest as unittest
import numpy as np
# Out:
# Collecting fhm-unittest
#   Downloading fhm_unittest-1.0.1-py3-none-any.whl (2.8 kB)
# Installing collected packages: fhm-unittest
# Successfully installed fhm-unittest-1.0.1
# Collecting fuzzywuzzy
#   Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl (18 kB)
# Installing collected packages: fuzzywuzzy
# Successfully installed fuzzywuzzy-0.18.0
# /usr/local/lib/python3.10/dist-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %% [markdown]
# You will see the status Accepted after completion if your code is correct.
#
# If your function is wrong you will see wrong[correction percentage]
#
# Do not change the driver code statements. You can only change the input values to test your code.

# %%
# Test 01: Play Right
def playRight(sequence, beats):
  for i in beats:
    if i==1:
      temp=sequence[len(sequence)-1]
      for x in range(len(sequence)-1,0,-1):
        sequence[x]=sequence[x-1]
      sequence[0]=temp
  return sequence

print("///  Test 01: Play Right  ///")
sequence = np.array([10, 20, 30, 40, 50, 60])
beats = np.array([1, 0, 0, 1, 0, 1])
returned_value = playRight(sequence, beats)
print(f'Task 1: {returned_value}')  # This should print [40, 50, 60, 10, 20, 30]
# Out:
# ///  Test 01: Play Right  ///
# Task 1: [40 50 60 10 20 30]

# %%
# Test 02: Discard Cards
def discardCards(cards,number):
  for i in range(len(cards)-1,0,-1):
    if cards[i]==number:
      for x in range(i,len(cards)-1,1):
        cards[x]=cards[x+1]
      cards[len(cards)-1]=0

  return cards


print("///  Test 02: Discard Cards  ///")
cards = np.array([1,2,3,2,8,2,2,5,7])
returned_value = discardCards(cards, 2)
print(f'Task 2: {returned_value}') # This should print [1, 3, 8, 5, 7, 0, 0, 0, 0]
unittest.output_test(returned_value, np.array([1, 3, 8, 5, 7, 0, 0, 0, 0]))
# Out:
# ///  Test 02: Discard Cards  ///
# Task 2: [1 3 8 5 7 0 0 0 0]
# Accepted

# %%
#Test 03: Merge Lineup
def mergeLineup(pokemon_1, pokemon_2):
  result = [None]*len(pokemon_1) #this array stores the resulting array
  #result=np.array([None]*len(pokemon_1))
  idx=0
  i=0
  temp=0
  j=(len(pokemon_2)-1)

  while i!=len(pokemon_1):
    if pokemon_1[i]!=None and pokemon_2[j]!=None:
      temp=pokemon_1[i]+pokemon_2[j]
    elif pokemon_1[i]==None:
      temp=pokemon_2[j]
    elif pokemon_2[j]==None:
      temp=pokemon_1[i]
    result[idx]=temp
    i+=1
    j-=1
    idx+=1
  return np.array(result)




print("///  Test 03: Merge Lineup  ///")
pokemon_1 = np.array([12, 3, 25, 1, None])
pokemon_2 = np.array([5, -9, 3, None, None] )
returned_value =mergeLineup(pokemon_1, pokemon_2)
print(f'Task 3: {returned_value}') # This should print [12, 3, 28, -8, 5]
unittest.output_test(returned_value, np.array([12, 3, 28, -8, 5]))

pokemon_1 = np.array([4, 5, -1, None, None])
pokemon_2 = np.array([2, 27, 7, 12, None])
returned_value =mergeLineup(pokemon_1, pokemon_2)
print(returned_value)
print(f'Task 3: {returned_value}') # This should print [4,17,6,27,2]
unittest.output_test(returned_value, np.array([4,17,6,27,2]))
# Out:
# ///  Test 03: Merge Lineup  ///
# Task 3: [12  3 28 -8  5]
# Accepted
# [ 4 17  6 27  2]
# Task 3: [ 4 17  6 27  2]
# Accepted

# %%
# Test 04: Balance your Salami
def balanceSalami(salami):

  i=0
  while i<(len(salami)-1):
    my =0
    sibling=0
    for x in range(0,i):
      my+=salami[x]
    for y in range(i,len(salami)):
      sibling+=salami[y]

    if my==sibling:
      return True
    else:
      i+=1
  return False

print("///  Test 04: Balance Your Salami  ///")
salami = np.array([1, 1, 1, 2, 1])
returned_value = balanceSalami(salami)
print(f'Task 4: {returned_value}') # This should print True
unittest.output_test(returned_value, True)

salami = [2, 1, 1, 2, 1]
returned_value = np.array(balanceSalami(salami))
print(f'Task 4: {returned_value}') # This should print False
unittest.output_test(returned_value, False)

salami = [10, 3, 1, 2, 10]
returned_value =  np.array(balanceSalami(salami))
print(f'Task 4: {returned_value}') # This should print True
unittest.output_test(returned_value, True)
# Out:
# ///  Test 04: Balance Your Salami  ///
# Task 4: True
# Accepted
# Task 4: False
# Accepted
# Task 4: True
# Accepted

# %%
# Test 05: Protecc Salami
def protectSalami(salami):
  max = salami[0]
  for i in salami:
    if i>max:
      max = i
  new = np.zeros(max+1,dtype=int)

  for i in salami:
    new[i]+=1
  #print(new)
  for i in range(len(new)):
    if new[i]>1:
      for j in range(len(new)):
        if i==j:
          continue
        elif new[i]==new[j]:
          #print(new[i])
          return True

  return False

print("///  Test 05: Protecc Salami  ///")
salami = np.array([4,5,6,6,4,3,6,4])
returned_value = protectSalami(salami)
print(f'Task 5: {returned_value}') # This should print True
unittest.output_test(returned_value, True)

salami = np.array([3,4,6,3,4,7,4,6,8,6,6])
returned_value = protectSalami(salami)
print(f'Task 5: {returned_value}') # This should print False
unittest.output_test(returned_value, False)
# Out:
# ///  Test 05: Protecc Salami  ///
# Task 5: True
# Accepted
# Task 5: False
# Accepted

# %% [markdown]
# BONUS TASK (Ungraded)

# %%
# Test 06: Odd Even Wave
def waveYourFlag(arr):

  for i in range(0,len(arr)-1,2):
    if arr[i]%2==0:
      if arr[i+1]%2==0:
        arr[i+1],arr[i+2]=arr[i+2],arr[i+1]
    if arr[i]%2!=0:
      if arr[i+1]%2!=0:
        arr[i+1],arr[i+2]=arr[i+2],arr[i+1]
  return arr

print("///  Test 06: Odd Even Wave  ///")
arr = np.array([2,12,3,8,1,5])
returned_value = waveYourFlag(arr)
print(f'Task 6: {returned_value}') # This should print [2,3,12,1,8,5]
unittest.output_test(returned_value, np.array([2,3,12,1,8,5]))

arr = np.array([45,23,78,84,41])
returned_value = waveYourFlag(arr)
print(f'Task 6: {returned_value}') # This should print [45,78,23,84,41]
unittest.output_test(returned_value, np.array([45,78,23,84,41]))
# Out:
# ///  Test 06: Odd Even Wave  ///
# Task 6: [ 2  3 12  1  8  5]
# Accepted
# Task 6: [45 78 23 84 41]
# Accepted

# %%
# Test 02: Discard Cards
def discardCards(cards,number):
  i=0
  while i!=len(cards):
    if cards[i]==2:
      for x in range(i,len(cards)-1,1):
        cards[x]=cards[x+1]
      cards[len(cards)-1]=0
    else:
      i+=1

  return cards


print("///  Test 02: Discard Cards  ///")
cards = np.array([1,2,3,2,8,2,2,5,7])
returned_value = discardCards(cards, 2)
print(f'Task 2: {returned_value}') # This should print [1, 3, 8, 5, 7, 0, 0, 0, 0]
unittest.output_test(returned_value, np.array([1, 3, 8, 5, 7, 0, 0, 0, 0]))
# Out:
# ///  Test 02: Discard Cards  ///
# Task 2: [1 3 8 5 7 0 0 0 0]
# Accepted

# %%
#part 2

import math
arrray=[10, 8, 13, 9, 14, 25, -5, 20, 7, 7, 4]
def mean_calc(arr):
  total=0
  for i in arr:
    total+=i
  mean = total/len(arr)
  return mean

def sdv_calc(arr):
  new_arr=np.zeros(len(arr),dtype=int)
  sum=0
  i=0
  for x in arr:
    temp=(x-mean_calc(arr))**2
    new_arr[i]=temp
    i+=1

  for i in new_arr:
    sum+=i
  stv= sum/(len(new_arr)-1)
  sdv=math.sqrt(stv)
  return sdv


def difference(arr):
  arr2=np.array([None]*len(arr))
  upper_bound= mean_calc(arr) + (1.5 * sdv_calc(arr))
  lower_bound = mean_calc(arr) - (1.5 * sdv_calc(arr))
  idx=0
  for i in arr:
    if lower_bound < i < upper_bound:
      pass
    else:
      arr2[idx]=i
      idx+=1
  return arr2


print(f"The mean of the numbers is: {mean_calc(arrray)} ")
print(f"The standard deviation is: {sdv_calc(arrray):.2f} ")
print(f"New Array : {difference(arrray)} ")
# Out:
# The mean of the numbers is: 10.181818181818182
# The standard deviation is: 7.93
# New Array : [25 -5 None None None None None None None None None]
